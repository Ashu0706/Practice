# %%
import re
with open('text.txt','r') as f:
    text = f.read()
    
print(text)
# Out:
# Hello Team,
#
# Please contact the following people for further information:
#
# 1. Primary Email: john.doe@gmail.com
# 2. Work Email: john_doe@company.co.in
# 3. Backup Email: support123@helpdesk.org
#
# Phone Numbers:
# - India Mobile: +91-9876543210
# - Alternate: 98765 43210
# - Office Landline: 022-24567890
# - US Contact: +1 (415) 555-2671
# - 5678234567
#
# Websites & URLs:
# - Official Site: https://www.example.com
# - Blog: http://blog.example.org/articles?id=45
# - FTP Server: ftp://files.server.net
#
# Dates:
# - Joined on: 12/08/2023
# - Contract ends: 2025-03-31
# - DOB: 01-01-1999
#
# IP Addresses:
# - Server IP: 192.168.1.1
# - Backup Server: 10.0.0.254
# - Public IP: 172.16.254.3
#
# Government IDs:
# - PAN: ABCDE1234F
# - Aadhaar: 1234 5678 9012
# - Passport: N1234567
#
# Prices & Amounts:
# - Product Price: ₹1,299.50
# - Discounted Price: $99.99
# - Subscription Fee: EUR 49
#
# Usernames & Handles:
# - GitHub: @john-doe_99
# - Twitter: @johnDoe
# ...

# %%
pattern = r'[6-9]\d{9}'
re.findall(pattern,text)
# Out:
# ['9876543210']

# %%
pattern = r'[a-zA-Z0-9]+@gmail.com' #ashu1303kr@gmail.com
re.findall(pattern,text)
# Out:
# ['doe@gmail.com']
